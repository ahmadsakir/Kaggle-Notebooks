# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadsakir/Kaggle-Notebooks/blob/main/Sentiment_Analysis_using_DisTilBeRT_96%25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('/content/drive/MyDrive/upload/twitter_sentimentt.csv')

# %%
df['tweet_contents'] = df['Tweet content']
df['labels'] = df['sentiment']

# %%
df.drop(['Tweet ID', 'entity', 'Tweet content', 'sentiment'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                       tweet_contents    labels
# 0  im getting on borderlands and i will murder yo...  Positive
# 1  I am coming to the borders and I will kill you...  Positive
# 2  im getting on borderlands and i will kill you ...  Positive
# 3  im coming on borderlands and i will murder you...  Positive
# 4  im getting on borderlands 2 and i will murder ...  Positive

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(4229)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 69767 entries, 0 to 74681
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_contents  69767 non-null  object
#  1   labels          69767 non-null  object
# dtypes: object(2)
# memory usage: 1.6+ MB

# %%
df['labels'].unique()
# Out:
# array(['Positive', 'Neutral', 'Negative', 'Irrelevant'], dtype=object)

# %%
fig = px.pie(df, names='labels', title='Sentiment Distribution')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# extracting only positive and negative sentiments data

df = df[(df['labels'] != 'Irrelevant') & (df['labels'] != 'Neutral')]

# %%
fig = px.pie(df, names='labels', title='Sentiment Distribution')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40374 entries, 0 to 74681
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_contents  40374 non-null  object
#  1   labels          40374 non-null  object
# dtypes: object(2)
# memory usage: 946.3+ KB

# %%
df['labels'] = df['labels'].map({'Positive':1, 'Negative':0})

# %%
df['labels'].unique()
# Out:
# array([1, 0])

# %%
df.head(10)
# Out:
#                                       tweet_contents  labels
# 0  im getting on borderlands and i will murder yo...       1
# 1  I am coming to the borders and I will kill you...       1
# 2  im getting on borderlands and i will kill you ...       1
# 3  im coming on borderlands and i will murder you...       1
# 4  im getting on borderlands 2 and i will murder ...       1
# 5  im getting into borderlands and i can murder y...       1
# 6  So I spent a few hours making something for fu...       1
# 7  So I spent a couple of hours doing something f...       1
# 8  So I spent a few hours doing something for fun...       1
# 9  So I spent a few hours making something for fu...       1

# %%
df['tweet_contents'] = df['tweet_contents'].str.lower()  # lowercasing the tweet

# %%
! pip install emoji
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 14.0 MB/s eta 0:00:00
# ...

# %%
import re
import spacy
import emoji
import string

def clean_text(text):
    text = re.sub(r'http\S+|www\S+|https\S+', '', text)   # Remove URLs
    text = re.sub(r'@\w+', '', text)  # remove mentions
    text = re.sub(r'#', '', text)   # remove hashtags
    text = re.sub(r'\S+@\S+', '', text)   # remove emails
    text = re.sub(r'&\w+;', '', text)    # remove html's
    text = emoji.replace_emoji(text, replace='')    # remove emojis
    text = text.translate(str.maketrans('', '', string.punctuation))   # remove punctuations
    text = re.sub(r'\s+', ' ', text).strip()   # remove extra spaces
    text = re.sub(r'\d+', '', text)   # remove digits

    return text

df['ctxt'] = df['tweet_contents'].apply(clean_text)

# %%
df.head(10)
# Out:
#                                       tweet_contents  labels  \
# 0  im getting on borderlands and i will murder yo...       1
# 1  i am coming to the borders and i will kill you...       1
# 2  im getting on borderlands and i will kill you ...       1
# 3  im coming on borderlands and i will murder you...       1
# 4  im getting on borderlands 2 and i will murder ...       1
# 5  im getting into borderlands and i can murder y...       1
# 6  so i spent a few hours making something for fu...       1
# 7  so i spent a couple of hours doing something f...       1
# 8  so i spent a few hours doing something for fun...       1
# 9  so i spent a few hours making something for fu...       1
#
#                                                 ctxt
# 0  im getting on borderlands and i will murder yo...
# 1  i am coming to the borders and i will kill you...
# 2  im getting on borderlands and i will kill you all
# 3  im coming on borderlands and i will murder you...
# ...

# %%
#python -m spacy download en_core_web_md

# %%
#python -m spacy download en_core_web_lg

# %%
'''spc = spacy.load('en_core_web_sm')

def transform_text(text):
      doc = spc(text)
      # Filter out lemmatize and non-alphabetic tokens , /stopwords not good for sentiment
      trans = [token.lemma_ for token in doc]
      return " ".join(trans)


df['trfo_text'] = df['CTxt'].apply(transform_text)'''
# Out:
# 'spc = spacy.load(\'en_core_web_sm\')\n\ndef transform_text(text):\n      doc = spc(text)\n      # Filter out lemmatize and non-alphabetic tokens , /stopwords not good for sentiment\n      trans = [token.lemma_ for token in doc]\n      return " ".join(trans)\n\n\ndf[\'trfo_text\'] = df[\'CTxt\'].apply(transform_text)'

# %%
df.drop(['tweet_contents'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    labels                                               ctxt
# 0       1  im getting on borderlands and i will murder yo...
# 1       1  i am coming to the borders and i will kill you...
# 2       1  im getting on borderlands and i will kill you all
# 3       1  im coming on borderlands and i will murder you...
# 4       1  im getting on borderlands  and i will murder y...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df['ctxt'], df['labels'], test_size=0.2, random_state=42, stratify=df['labels'])

# %%
from transformers import DistilBertTokenizerFast, DistilBertForSequenceClassification
import torch
from torch.utils.data import DataLoader, Dataset
from torch.optim import AdamW
from sklearn.metrics import accuracy_score, classification_report

# Initialize the DistilBERT tokenizer
tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased')

# Tokenize the text data
train_encodings = tokenizer(X_train.tolist(),
                            truncation=True,
                            padding=True,
                            max_length=512)

test_encodings = tokenizer(X_test.tolist(),
                          truncation=True,
                          padding=True,
                          max_length=512)

# %%
# Create a custom PyTorch Dataset class

class SentimentDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels.iloc[idx], dtype=torch.long)
        return item

    def __len__(self):
        return len(self.labels)

# Create instances of the custom dataset
traint_dataset = SentimentDataset(train_encodings, y_train)
test_dataset = SentimentDataset(test_encodings, y_test)

# Create DataLoaders to handle batching
train_loader = DataLoader(traint_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
# Set up the device for training (GPU or CPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Initialize the DistilBERT model for sequence classification
model = DistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=2)
model.to(device)
model.train()

# Set up the optimizer
optimizer = AdamW(model.parameters(), lr=5e-5)
# Out:
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Training loop
epochs = 3 # You can adjust this number
for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")
    model.train()
    for batch in train_loader:
        # Move batch data to the correct device
        optimizer.zero_grad()
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        # Forward pass
        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

    print(f"Loss: {loss.item()}")
# Out:
# Epoch 1/3
# Loss: 0.11594074219465256
# Epoch 2/3
# Loss: 0.21616621315479279
# Epoch 3/3
# Loss: 0.03643348440527916

# %%
# Evaluation loop
model.eval()
val_preds = []
val_true = []

with torch.no_grad():
    for batch in test_loader:
        # Move batch data to the correct device
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        # Forward pass
        outputs = model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits
        predictions = torch.argmax(logits, dim=-1)

        val_preds.extend(predictions.cpu().numpy())
        val_true.extend(labels.cpu().numpy())

# Calculate and print the accuracy
accuracy = accuracy_score(val_true, val_preds)
print(f"Validation Accuracy: {accuracy:.4f}")

# Print the classification report for more detailed metrics
print("\nClassification Report:")
print(classification_report(val_true, val_preds))
# Out:
# Validation Accuracy: 0.9563
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      4248
#            1       0.95      0.96      0.95      3827
#
#     accuracy                           0.96      8075
#    macro avg       0.96      0.96      0.96      8075
# weighted avg       0.96      0.96      0.96      8075
